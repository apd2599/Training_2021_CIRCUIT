# %%
import numpy as np
import pandas as pd
import seaborn as sns
import graphviz
import matplotlib.pyplot as plt
from sklearn import random_projection
from sklearn.preprocessing import StandardScaler
from sklearn import datasets
from sklearn.svm import SVC
from sklearn import svm
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score
from sklearn import tree

# %%
wine = datasets.load_wine()

# %%
print(wine['DESCR'])
# Out:
# .. _wine_dataset:
#
# Wine recognition dataset
# ------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 178 (50 in each of three classes)
#     :Number of Attributes: 13 numeric, predictive attributes and the class
#     :Attribute Information:
#  		- Alcohol
#  		- Malic acid
#  		- Ash
# 		- Alcalinity of ash
#  		- Magnesium
# 		- Total phenols
#  		- Flavanoids
#  		- Nonflavanoid phenols
#  		- Proanthocyanins
# 		- Color intensity
#  		- Hue
#  		- OD280/OD315 of diluted wines
#  		- Proline
#
#     - class:
#             - class_0
#             - class_1
#             - class_2
#
#     :Summary Statistics:
#
#     ============================= ==== ===== ======= =====
#                                    Min   Max   Mean     SD
#     ============================= ==== ===== ======= =====
#     Alcohol:                      11.0  14.8    13.0   0.8
#     Malic Acid:                   0.74  5.80    2.34  1.12
# ...

# %% [markdown]
# # Data Preprocessing

# %%
data = wine['data']
target = wine['target']
features = wine['feature_names']

# %%
data
# Out:
# array([[1.423e+01, 1.710e+00, 2.430e+00, ..., 1.040e+00, 3.920e+00,
#         1.065e+03],
#        [1.320e+01, 1.780e+00, 2.140e+00, ..., 1.050e+00, 3.400e+00,
#         1.050e+03],
#        [1.316e+01, 2.360e+00, 2.670e+00, ..., 1.030e+00, 3.170e+00,
#         1.185e+03],
#        ...,
#        [1.327e+01, 4.280e+00, 2.260e+00, ..., 5.900e-01, 1.560e+00,
#         8.350e+02],
#        [1.317e+01, 2.590e+00, 2.370e+00, ..., 6.000e-01, 1.620e+00,
#         8.400e+02],
#        [1.413e+01, 4.100e+00, 2.740e+00, ..., 6.100e-01, 1.600e+00,
#         5.600e+02]])

# %%
data_ss = StandardScaler().fit_transform(data)
Xdf = pd.DataFrame(data_ss, columns=features)
ys = pd.Series(target)

# %%
Xdf
# Out:
#       alcohol  malic_acid       ash  alcalinity_of_ash  magnesium  \
# 0    1.518613   -0.562250  0.232053          -1.169593   1.913905
# 1    0.246290   -0.499413 -0.827996          -2.490847   0.018145
# 2    0.196879    0.021231  1.109334          -0.268738   0.088358
# 3    1.691550   -0.346811  0.487926          -0.809251   0.930918
# 4    0.295700    0.227694  1.840403           0.451946   1.281985
# ..        ...         ...       ...                ...        ...
# 173  0.876275    2.974543  0.305159           0.301803  -0.332922
# 174  0.493343    1.412609  0.414820           1.052516   0.158572
# 175  0.332758    1.744744 -0.389355           0.151661   1.422412
# 176  0.209232    0.227694  0.012732           0.151661   1.422412
# 177  1.395086    1.583165  1.365208           1.502943  -0.262708
#
#      total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# 0         0.808997    1.034819             -0.659563         1.224884
# ...

# %%
ys
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 173    2
# 174    2
# 175    2
# 176    2
# 177    2
# Length: 178, dtype: int64

# %%
Xdf.columns
# Out:
# Index(['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium',
#        'total_phenols', 'flavanoids', 'nonflavanoid_phenols',
#        'proanthocyanins', 'color_intensity', 'hue',
#        'od280/od315_of_diluted_wines', 'proline'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis

# %%
Xdf.alcohol.hist()
# Out:
# <AxesSubplot:>

# %%
Xdf[['alcohol','malic_acid','ash','alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'color_intensity']].corr()
# Out:
#                     alcohol  malic_acid       ash  alcalinity_of_ash  \
# alcohol            1.000000    0.094397  0.211545          -0.310235
# malic_acid         0.094397    1.000000  0.164045           0.288500
# ash                0.211545    0.164045  1.000000           0.443367
# alcalinity_of_ash -0.310235    0.288500  0.443367           1.000000
# magnesium          0.270798   -0.054575  0.286587          -0.083333
# total_phenols      0.289101   -0.335167  0.128980          -0.321113
# flavanoids         0.236815   -0.411007  0.115077          -0.351370
# color_intensity    0.546364    0.248985  0.258887           0.018732
#
#                    magnesium  total_phenols  flavanoids  color_intensity
# alcohol             0.270798       0.289101    0.236815         0.546364
# malic_acid         -0.054575      -0.335167   -0.411007         0.248985
# ash                 0.286587       0.128980    0.115077         0.258887
# ...

# %%
for i in Xdf.columns:
    cat_num = Xdf[i].value_counts()
    print("graph for %s: total = %d" % (i, len(cat_num)))
    chart = sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# graph for alcohol: total = 126
# graph for malic_acid: total = 133
# graph for ash: total = 79
# graph for alcalinity_of_ash: total = 63
# graph for magnesium: total = 53
# graph for total_phenols: total = 97
# graph for flavanoids: total = 132
# graph for nonflavanoid_phenols: total = 39
# graph for proanthocyanins: total = 101
# graph for color_intensity: total = 132
# graph for hue: total = 78
# graph for od280/od315_of_diluted_wines: total = 122
# graph for proline: total = 121

# %%
clf = svm.SVC()

# %%
X_train, X_test, y_train, y_test = train_test_split(Xdf, ys, test_size=0.2, random_state=42)

# %%
clf.fit(X_train, y_train)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
y_pred = clf.predict(X_test)

# %%
print(accuracy_score(ytest, ypred))
print(precision_score(ytest, ypred))
print(recall_score(ytest, ypred))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-4f7dfa230c64> in <module>
# ----> 1 print(accuracy_score(ytest, ypred))
#       2 print(precision_score(ytest, ypred))
#       3 print(recall_score(ytest, ypred))
#
# NameError: name 'ytest' is not defined
