# %%
import pandas as pd
import numpy as np
import random as rnd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
file_path = 'healthcare-dataset-stroke-data.csv'
data = pd.read_csv(file_path)

# %%
shuffled_data = data.sample(frac=1)

# %%
print(shuffled_data)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 1411  29375    Male  62.0             0              0          Yes
# 790   22384  Female  24.0             0              0          Yes
# 4854   8838  Female  36.0             0              0           No
# 4102  30129  Female  62.0             0              0          Yes
# 1467  47627    Male   8.0             0              0           No
# ...     ...     ...   ...           ...            ...          ...
# 3892  47803    Male  37.0             0              0          Yes
# 1747  33906    Male  51.0             0              0          Yes
# 1528  11770  Female  25.0             0              0          Yes
# 2665  24965  Female  25.0             0              0           No
# 4687  63022  Female  59.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi smoking_status  \
# 1411        Private          Urban             206.98  36.8         smokes
# 790         Private          Rural              97.92  23.1   never smoked
# 4854        Private          Rural              66.55  32.8         smokes
# 4102       Govt_job          Urban             163.17  25.6   never smoked
# 1467       children          Urban             107.69  20.3        Unknown
# ...             ...            ...                ...   ...            ...
# 3892       Govt_job          Urban             173.97  26.3        Unknown
# 1747       Govt_job          Urban              92.32  34.7         smokes
# 1528       Govt_job          Urban              93.23   NaN         smokes
# 2665       Govt_job          Rural             103.15  21.0         smokes
# 4687  Self-employed          Urban              88.10  30.7   never smoked
#
#       stroke
# 1411       0
# 790        0
# 4854       0
# 4102       0
# 1467       0
# ...      ...
# 3892       0
# 1747       0
# 1528       0
# 2665       0
# 4687       0
#
# [5110 rows x 12 columns]

# %%
split = int(len(shuffled_data)*.7)
train_df = shuffled_data[:split]
test_df = shuffled_data[split:]

# %%
train_df.head()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 1411  29375    Male  62.0             0              0          Yes   Private
# 790   22384  Female  24.0             0              0          Yes   Private
# 4854   8838  Female  36.0             0              0           No   Private
# 4102  30129  Female  62.0             0              0          Yes  Govt_job
# 1467  47627    Male   8.0             0              0           No  children
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 1411          Urban             206.98  36.8         smokes       0
# 790           Rural              97.92  23.1   never smoked       0
# 4854          Rural              66.55  32.8         smokes       0
# 4102          Urban             163.17  25.6   never smoked       0
# 1467          Urban             107.69  20.3        Unknown       0

# %%
test_df.head()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 2136  59745  Female  27.0             0              0          Yes
# 916   67864    Male  63.0             0              0          Yes
# 4449  47144  Female  74.0             0              0          Yes
# 51    15102    Male  78.0             1              0          Yes
# 2236  20673    Male  39.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 2136        Private          Urban              76.74  53.9          Unknown
# 916         Private          Rural              57.82  28.8  formerly smoked
# 4449  Self-employed          Urban              88.62  28.5  formerly smoked
# 51          Private          Urban              75.32   NaN  formerly smoked
# 2236        Private          Rural             102.35  23.6     never smoked
#
#       stroke
# 2136       0
# 916        0
# 4449       0
# 51         1
# 2236       0

# %%
#def X_and_y_from_df(df, y_column, X_columns = []):
#    X = {}
#    for feature in X_columns:
#        X[feature] = df[feature].tolist()
#    y = df[y_column].tolist()
#    return X, y

# %%
#X_train, y_train = X_and_y_from_df(train_df, 'age', ['stroke'])
#X_test, y_test = X_and_y_from_df(test_df, 'age', ['stroke'])

# %%
#X_train_arr = np.array(X_train['stroke'])
#X_train_arr = X_train_arr.reshape(X_train_arr.shape[0], 1)
#X_test_arr = np.array(X_test['stroke'])
#X_test_arr = X_test_arr.reshape(X_test_arr.shape[0], 1)

# %%
#model = LinearRegression()
#model.fit(X_train_arr, y_train)

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
data.age.hist()
# Out:
# <AxesSubplot:>

# %%
data.iterrows
#data.apply(lambda x: data[i])
# Out:
# <bound method DataFrame.iterrows of          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]>

# %%
data_new = data[data['stroke'] == 1]

# %%
data_new.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# 75%           114.090000    33.100000     0.000000
# max           271.740000    97.600000     1.000000

# %%
data_new.describe()
# Out:
#                  id         age  hypertension  heart_disease  \
# count    249.000000  249.000000    249.000000     249.000000
# mean   37115.068273   67.728193      0.265060       0.188755
# std    21993.344872   12.727419      0.442254       0.392102
# min      210.000000    1.320000      0.000000       0.000000
# 25%    17013.000000   59.000000      0.000000       0.000000
# 50%    36706.000000   71.000000      0.000000       0.000000
# 75%    56669.000000   78.000000      1.000000       0.000000
# max    72918.000000   82.000000      1.000000       1.000000
#
#        avg_glucose_level         bmi  stroke
# count         249.000000  209.000000   249.0
# mean          132.544739   30.471292     1.0
# std            61.921056    6.329452     0.0
# min            56.110000   16.900000     1.0
# 25%            79.790000   26.400000     1.0
# 50%           105.220000   29.700000     1.0
# 75%           196.710000   33.700000     1.0
# max           271.740000   56.600000     1.0

# %%
data_new.age.hist()
# Out:
# <AxesSubplot:>

# %%
data.age.hist()
# Out:
# <AxesSubplot:>

# %%
data_new2 = data[data['stroke'] == 0]

# %%
data_new2.age.hist()
# Out:
# <AxesSubplot:>
